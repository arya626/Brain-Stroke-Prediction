# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("full_data.csv")

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
plt.figure(figsize = (12,8))
sns.countplot(data['gender'])
# sns.countplot(data['stroke'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
data.loc[(data['gender'] == 'Male') & (data['stroke'] == 1)]
# Out:
#      gender   age  hypertension  heart_disease ever_married      work_type  \
# 0      Male  67.0             0              1          Yes        Private
# 1      Male  80.0             0              1          Yes        Private
# 4      Male  81.0             0              0          Yes        Private
# 5      Male  74.0             1              1          Yes        Private
# 13     Male  64.0             0              1          Yes        Private
# ...     ...   ...           ...            ...          ...            ...
# 4814   Male  61.0             0              1          Yes        Private
# 4815   Male  79.0             0              0          Yes        Private
# 4816   Male  74.0             0              0          Yes        Private
# 4818   Male  74.0             0              0          Yes  Self-employed
# 4819   Male  71.0             1              0          Yes  Self-employed
#
# ...

# %%
data.loc[(data['gender'] == 'Male') & (data['stroke'] == 0)]
# Out:
#      gender   age  hypertension  heart_disease ever_married work_type  \
# 208    Male   3.0             0              0           No  children
# 209    Male  58.0             1              0          Yes   Private
# 216    Male  79.0             0              1          Yes   Private
# 220    Male  35.0             0              0           No   Private
# 227    Male  71.0             0              0          Yes   Private
# ...     ...   ...           ...            ...          ...       ...
# 4974   Male  58.0             0              0          Yes  Govt_job
# 4975   Male  31.0             0              0           No   Private
# 4976   Male  41.0             0              0           No   Private
# 4977   Male  40.0             0              0          Yes   Private
# 4979   Male  40.0             0              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# ...

# %%
data.loc[(data['gender'] == 'Female') & (data['stroke'] == 1)]
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 6     Female  69.0             0              0           No        Private
# 7     Female  78.0             0              0          Yes        Private
# 8     Female  81.0             1              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4810  Female  79.0             1              1           No  Self-employed
# 4811  Female  78.0             0              0          Yes  Self-employed
# 4812  Female  80.0             0              0          Yes       Govt_job
# 4813  Female  77.0             0              0           No        Private
# 4817  Female  76.0             1              1          Yes  Self-employed
#
# ...

# %%
data.loc[(data['gender'] == 'Female') & (data['stroke'] == 0)]
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 210   Female   8.0             0              0           No        Private
# 211   Female  70.0             0              0          Yes        Private
# 212   Female  52.0             0              0          Yes        Private
# 213   Female  75.0             0              1          Yes  Self-employed
# 214   Female  32.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4968  Female  78.0             1              1          Yes        Private
# 4969  Female  70.0             0              1          Yes  Self-employed
# 4970  Female  70.0             0              1          Yes  Self-employed
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
sns.barplot(x = "gender", y = 'stroke', data = data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='stroke'>

# %%
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...
